# %%
import pandas as pd

# %%
df=pd.read_csv('Car Dataset Processed.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df=pd.read_csv('Car Dataset Processed.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission  manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic                2017           7.81      2996.0
# ...

# %%
df['insurance_validity'].value_counts()
# Out:
# insurance_validity
# Comprehensive            1081
# Third Party insurance     289
# Zero Dep                   64
# Third Party                63
# Not Available               2
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    997
# Diesel    480
# CNG        22
# Name: count, dtype: int64

# %%
df['ownsership'].value_counts()
# Out:
# ownsership
# First Owner     1236
# Second Owner     240
# Third Owner       21
# Fifth Owner        2
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       832
# Automatic    667
# Name: count, dtype: int64

# %%
df['insurance_validity'] = df['insurance_validity'].map({'Comprenensive':0,'Third party insurance':1,
                                                         'zero Dep':2,'Not Aailable':3,'Third Party':1})

# %%
df['insurance_validity'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    997
# Diesel    480
# CNG        22
# Name: count, dtype: int64

# %%
df['insurance_validity'].value_counts()
# Out:
# insurance_validity
# 1.0    63
# Name: count, dtype: int64

# %%
df['ownsership'].value_counts()
# Out:
# ownsership
# First Owner     1236
# Second Owner     240
# Third Owner       21
# Fifth Owner        2
# Name: count, dtype: int64

# %%
df['insurance_validity'] = df['insurance_validity'].map({'Comprenensive':0,'Third party insurance':1,
                                                         'zero Dep':2,'Not Aailable':3,'Third Party':1})

# %%
df['insurance_validity'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['fuel_type']=df['fuel_type'].map({'petrol':0,'Diesel':1,'CNG':2})

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# 1.0    480
# 2.0     22
# Name: count, dtype: int64

# %%
df['ownsership'].map({'first_owner':1,'second_owner':2,'third_owner':3,'fifth_owner':5})
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1494   NaN
# 1495   NaN
# 1496   NaN
# 1497   NaN
# 1498   NaN
# Name: ownsership, Length: 1499, dtype: float64

# %%
df['registration_year']
# Out:
# 0       Jul-17
# 1       Jan-21
# 2       Sep-18
# 3       Dec-19
# 4       Aug-19
#          ...
# 1494    May-22
# 1495    Aug-20
# 1496    Jun-17
# 1497    May-18
# 1498    May-18
# Name: registration_year, Length: 1499, dtype: object

# %%
X = df[['insurance_validity','fuel_type','ownsership','transmission']]
y = df['price(in lakhs)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 X = df[['insurance_validity','fuel_type','ownsership','transmission']]
#       2 y = df['price(in lakhs)']
#
# NameError: name 'df' is not defined

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
models = {
    'LinReg': LinearRegression(),
    'KNN-3': KNeighborsRegressor(n_neighbors=3),
    'SVM-Poly': SVR(kernel='poly')
}


for name, model in models.items():
    model.fit(X, y)
    score = model.score(X, y)
    print(name, score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       1 models = {
#       2     'LinReg': LinearRegression(),
#       3     'KNN-3': KNeighborsRegressor(n_neighbors=3),
#       4     'SVM-Poly': SVR(kernel='poly')
#       5 }
#       8 for name, model in models.items():
# ----> 9     model.fit(X, y)
#      10     score = model.score(X, y)
#      11     print(name, score)
#
# NameError: name 'X' is not defined

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR


df = pd.read_csv('Car Dataset Processed.csv')


df['insurance_validity'] = df['insurance_validity'].map({'Comprehensive':0 , 'Third Party insurance':1 , 'Zero Dep' : 2, 'Not Available' : 3 ,'Third Party' : 4})

df['fuel_type'] = df['fuel_type'].map({'Petrol':0 , 'Diesel':1 , 'CNG' : 2})

df['ownsership'] = df['ownsership'].map({'First Owner':0 , 'Second Owner':1 , 'Third Owner' : 3 ,'Fifth Owner': 5 })

df['transmission'] = df['transmission'].map({'Manual':0 , 'Automatic':1 })




X = df[['insurance_validity','fuel_type','ownsership','transmission']]
y = df['price(in lakhs)']


models = {
    'LinReg': LinearRegression(),
    'KNN-3': KNeighborsRegressor(n_neighbors=3),
    'SVM-Poly': SVR(kernel='poly')
}


for name, model in models.items():
    model.fit(X, y)
    score = model.score(X, y)
    print(name, score)
# Out:
# LinReg 0.022231167562926424
# KNN-3 -0.002233046848794551
# SVM-Poly -0.0022217055897646443

# %%
final_model =models['KNN-3']

# %%
d1={'Comprehensive': 0,'Third Party insurance': 1,'Zero Dep': 2,'Not Available': 3,'Third Party': 1}
d2={'Petrol': 0, 'Diesel': 1, 'CNG': 2}
d3={'Manual': 0, 'Automatic': 1}
d4={'First Owner': 1,'Second Owner': 2,'Third Owner': 3,'Fifth Owner': 5,'Fourth Owner': 4}

# %%
insurance_validity = input('Insurance validity:')
fuel_type = input('Fuel Type:')
kms_driven = input('KMs Drive:')
ownsership = input('Ownership:')
transmission = input('Transmission Type:')
insurance_validity = d1[insurance_validity]
fuel_type = d2[fuel_type]
transmission = d3[transmission]
ownsership = d4[ownsership]
kms_driven = int(kms_driven)
test = [[insurance_validity,fuel_type,kms_driven,ownsership,transmission]]
yp = int(final_model.predict(test)[0])
print('Predicted Car Price is {} Rs.'.format(yp))
# Out:
# Insurance validity:  Zero Dep
# Fuel Type:  Petrol
# KMs Drive:  200000
# Ownership:  Second Owner
# Transmission Type:  Automatic
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 6
#       4 ownsership = input('Ownership:')
#       5 transmission = input('Transmission Type:')
# ----> 6 insurance_validity = d1[insurance_validity]
#       7 fuel_type = d2[fuel_type]
#       8 transmission = d3[transmission]
#
# KeyError: ' Zero Dep'

# %%
import pickle

pickle.dump(model, open('car_price_model.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pickle
# ----> 3 pickle.dump(model, open('car_price_model.pkl', 'wb'))
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR


df = pd.read_csv('Car Dataset Processed.csv')


df['insurance_validity'] = df['insurance_validity'].map({'Comprehensive':0 , 'Third Party insurance':1 , 'Zero Dep' : 2, 'Not Available' : 3 ,'Third Party' : 4})

df['fuel_type'] = df['fuel_type'].map({'Petrol':0 , 'Diesel':1 , 'CNG' : 2})

df['ownsership'] = df['ownsership'].map({'First Owner':0 , 'Second Owner':1 , 'Third Owner' : 3 ,'Fifth Owner': 5 })

df['transmission'] = df['transmission'].map({'Manual':0 , 'Automatic':1 })




X = df[['insurance_validity','fuel_type','ownsership','transmission']]
y = df['price(in lakhs)']


models = {
    'LinReg': LinearRegression(),
    'KNN-3': KNeighborsRegressor(n_neighbors=3),
    'SVM-Poly': SVR(kernel='poly')
}


for name, model in models.items():
    model.fit(X, y)
    score = model.score(X, y)
    print(name, score)
# Out:
# LinReg 0.022231167562926424
# KNN-3 -0.002233046848794551
# SVM-Poly -0.0022217055897646443

# %%
final_model =models['KNN-3']

# %%
d1={'Comprehensive': 0,'Third Party insurance': 1,'Zero Dep': 2,'Not Available': 3,'Third Party': 1}
d2={'Petrol': 0, 'Diesel': 1, 'CNG': 2}
d3={'Manual': 0, 'Automatic': 1}
d4={'First Owner': 1,'Second Owner': 2,'Third Owner': 3,'Fifth Owner': 5,'Fourth Owner': 4}

# %%
insurance_validity = input('Insurance validity:')
fuel_type = input('Fuel Type:')
kms_driven = input('KMs Drive:')
ownsership = input('Ownership:')
transmission = input('Transmission Type:')
insurance_validity = d1[insurance_validity]
fuel_type = d2[fuel_type]
transmission = d3[transmission]
ownsership = d4[ownsership]
kms_driven = int(kms_driven)
test = [[insurance_validity,fuel_type,kms_driven,ownsership,transmission]]
yp = int(final_model.predict(test)[0])
print('Predicted Car Price is {} Rs.'.format(yp))
# Out:
# Insurance validity: Zero Dep
# Fuel Type: Petrol
# KMs Drive: 200000
# Ownership: Second Owner
# Transmission Type: Automatic
# C:\Users\gitey\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#      10 kms_driven = int(kms_driven)
#      11 test = [[insurance_validity,fuel_type,kms_driven,ownsership,transmission]]
# ---> 12 yp = int(final_model.predict(test)[0])
#      13 print('Predicted Car Price is {} Rs.'.format(yp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_regression.py:243, in KNeighborsRegressor.predict(self, X)
#     225 """Predict the target for the provided data.
#     226
#     227 Parameters
#    (...)    238     Target values.
#     239 """
# ...

# %% [markdown]
# # Assistant
# This error occurs because your model was trained with 4 features, but you're trying to predict with 5 features.
#
# The error message indicates that your `final_model` (which is a KNeighborsRegressor) expects 4 input features, but you're providing 5 features in your `test` list.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
insurance_validity = input('Insurance validity:')
fuel_type = input('Fuel Type:')
kms_driven = input('KMs Drive:')
ownsership = input('Ownership:')
transmission = input('Transmission Type:')
insurance_validity = d1[insurance_validity]
fuel_type = d2[fuel_type]
transmission = d3[transmission]
ownsership = d4[ownsership]
kms_driven = int(kms_driven)

# Remove one of the features to match the model's expected input
# For example, let's assume we need to remove 'transmission'
# You should check your model to determine which 4 features it expects
test = [[insurance_validity, fuel_type, kms_driven, ownsership]]  # Removed transmission

yp = int(final_model.predict(test)[0])
print('Predicted Car Price is {} Rs.'.format(yp))
# Out:
# Insurance validity: Zero Dep
# Fuel Type: Petrol
# KMs Drive: 200000
# Ownership: Second Owner
# Transmission Type: Automatic
# Predicted Car Price is 7 Rs.
# C:\Users\gitey\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Note: You need to determine which 4 features your model was trained on and make sure you're using exactly those features in the same order. I've removed 'transmission' as an example, but you should check your model documentation or training code to confirm which features to include.

# %% [markdown]
# # Assistant
# This error occurs because your model was trained with 4 features, but you're trying to predict with 5 features.
#
# The error message indicates that your `final_model` (which is a KNeighborsRegressor) expects 4 input features, but you're providing 5 features in your `test` list.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
insurance_validity = input('Insurance validity:')
fuel_type = input('Fuel Type:')
kms_driven = input('KMs Drive:')
ownsership = input('Ownership:')
transmission = input('Transmission Type:')
insurance_validity = d1[insurance_validity]
fuel_type = d2[fuel_type]
transmission = d3[transmission]
ownsership = d4[ownsership]
kms_driven = int(kms_driven)

# Remove one of the features to match the model's expected input
# For example, let's assume we need to remove 'transmission'
# You should check your model to determine which 4 features it expects
test = [[insurance_validity, fuel_type, kms_driven, ownsership]]  # Removed transmission

yp = int(final_model.predict(test)[0])
print('Predicted Car Price is {} Rs.'.format(yp))
# Out:
# Insurance validity: Zero Dep
# Fuel Type: Petrol
# KMs Drive: 200000
# Ownership: Second Owner
# Transmission Type: Automatic
# Predicted Car Price is 7 Rs.
# C:\Users\gitey\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Note: You need to determine which 4 features your model was trained on and make sure you're using exactly those features in the same order. I've removed 'transmission' as an example, but you should check your model documentation or training code to confirm which features to include.

# %%
import pickle

pickle.dump(model, open('car_price_model.pkl', 'wb'))
